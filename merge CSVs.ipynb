# %%
import glob
from os import path
from scrapers.scrapetools import Results
import pandas as pd
import csv

# %%
p = 'data\\afnor\\out'
out = 'data\\afnor\\out.csv'
inc = 'data\\afnor\\found.csv'

# %%
inputs = glob.glob(path.join(p, "*.csv")) + [inc]
df = pd.concat((pd.read_csv(f, sep=";", quotechar="\"", encoding="ISO-8859-1") for f in inputs), axis=0, ignore_index=True)
# Out:
# C:\Users\phess\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DtypeWarning: Columns (21,23,29) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
df.to_csv(out, sep=";", index=False, quotechar='"', quoting=csv.QUOTE_ALL)

# %%
df.describe(include='all')
# Out:
#                               Amended by                     Amending  \
# count                              13324                        16252
# unique                              3689                         4383
# top     NF C13-200 F1:201105 (C13-200F1)  NF C15-100:200212 (C15-100)
# freq                                  50                          117
# mean                                 NaN                          NaN
# std                                  NaN                          NaN
# min                                  NaN                          NaN
# 25%                                  NaN                          NaN
# 50%                                  NaN                          NaN
# 75%                                  NaN                          NaN
# max                                  NaN                          NaN
#
#        Classification index  \
# count                210741
# unique                51249
# top                 P90-308
# freq                    111
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN
#
#        Commission mandate for the            standard, given to the CEN, in the           framework of a European directive  \
# count                                              216940
# unique                                                  2
# top                                                    No
# freq                                               211115
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         Copied in Document for revision  Document type  \
# count       26005                216940         216940
# unique        778                     2              4
# top     3179421CD                    No  ST (Standard)
# freq         1368                207890         210837
# mean          NaN                   NaN            NaN
# std           NaN                   NaN            NaN
# min           NaN                   NaN            NaN
# 25%           NaN                   NaN            NaN
# 50%           NaN                   NaN            NaN
# 75%           NaN                   NaN            NaN
# max           NaN                   NaN            NaN
#
#                                       English descriptors  \
# count                                              210925
# unique                                              53372
# top     TELECOMMUNICATION; LOCAL AREA NETWORKS; COMMUN...
# freq                                                  126
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                             English title  \
# count                                              206916
# unique                                              60452
# top     Protective elements for in-ground, barrier-fre...
# freq                                                  128
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                        French descriptors     ...       \
# count                                              210931     ...
# unique                                              53333     ...
# top     TELECOMMUNICATION; RESEAU LOCAL; CABLE DE TELE...     ...
# freq                                                  126     ...
# mean                                                  NaN     ...
# std                                                   NaN     ...
# min                                                   NaN     ...
# 25%                                                   NaN     ...
# 50%                                                   NaN     ...
# 75%                                                   NaN     ...
# max                                                   NaN     ...
#
#                        Replacing  \
# count                      86666
# unique                     25703
# top     E66-000:199412 (E66-000)
# freq                          94
# mean                         NaN
# std                          NaN
# min                          NaN
# 25%                          NaN
# 50%                          NaN
# 75%                          NaN
# max                          NaN
#
#                                           Replacing later  \
# count                                                3299
# unique                                                978
# top     NF EN 60601-1:199102 (C74-011)\r\n,\r\n\r\nNF ...
# freq                                                   35
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                       Revision drafts identifiers  \
# count                                        9583
# unique                                       2474
# top     PR NF EN ISO 16090-1:201410 (E60-421-1PR)
# freq                                           81
# mean                                          NaN
# std                                           NaN
# min                                           NaN
# 25%                                           NaN
# 50%                                           NaN
# 75%                                           NaN
# max                                           NaN
#
#                          Revision of Selling Withdrawal date  \
# count                           6067  216805          106782
# unique                          2833       3            2436
# top     NF ISO 7001:200801 (X05-010)   AFNOR      2010-01-28
# freq                              34  168062            3904
# mean                             NaN     NaN             NaN
# std                              NaN     NaN             NaN
# min                              NaN     NaN             NaN
# 25%                              NaN     NaN             NaN
# 50%                              NaN     NaN             NaN
# 75%                              NaN     NaN             NaN
# max                              NaN     NaN             NaN
#
#                                                   html_en  \
# count                                               12970
# unique                                               4428
# top     /en-US/sw/Consultation/Xml/1274240/?lng=EN&sup...
# freq                                                   32
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                   html_fr  \
# count                                              154784
# unique                                              44396
# top     /en-US/sw/Consultation/Xml/1277830/?lng=FR&sup...
# freq                                                   94
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                   members        query
# count                                              108659       217287
# unique                                              32627        12986
# top     ABRAHAM : BULL SA|ALARD : WAVECOM|ALIAGA : EUR...  NF EN 60335
# freq                                                  355         4760
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
# [11 rows x 42 columns]

# %%
cols = df.columns.tolist()
print(cols)
# Out:
# ['Amended by', 'Amending', 'Classification index', 'Commission mandate for the            standard, given to the CEN, in the           framework of a European directive', 'Copied in', 'Document for revision', 'Document type', 'English descriptors', 'English title', 'French descriptors', 'French summary', 'French title', 'Harmonised standard', 'ICS topics', 'Investigation end date', 'Is replaced later by', 'Mandatory implementation by', 'Mandatory standard', 'NF brand medium', 'New approach directive', 'Note', 'Number NOR', 'Official identifier', 'Pages/Format', 'Partly replaced by', 'Partly replacing', 'Price (Before Duties)', 'Publication date', 'Publication target date', 'Published in', 'Quoted reference(s)', 'Replaced by', 'Replacing', 'Replacing later', 'Revision drafts identifiers', 'Revision of', 'Selling', 'Withdrawal date', 'html_en', 'html_fr', 'members', 'query']

# %%
withdrawn = df.drop_duplicates(subset=['Official identifier'])
withdrawn.describe(include='all')
# Out:
#                                   Amended by                        Amending  \
# count                                   2626                            5712
# unique                                  2614                            4132
# top     NF C48-XXX F/AC:199912 (C48-XXXF/AC)  NF EN 60061-1:199308 (C61-501)
# freq                                       6                              42
# mean                                     NaN                             NaN
# std                                      NaN                             NaN
# min                                      NaN                             NaN
# 25%                                      NaN                             NaN
# 50%                                      NaN                             NaN
# 75%                                      NaN                             NaN
# max                                      NaN                             NaN
#
#        Classification index  \
# count                 56663
# unique                50770
# top                 S51-212
# freq                      8
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN
#
#        Commission mandate for the            standard, given to the CEN, in the           framework of a European directive  \
# count                                               60309
# unique                                                  2
# top                                                    No
# freq                                                59004
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         Copied in Document for revision  Document type  \
# count        5957                 60309          60309
# unique        689                     2              4
# top     3052711CD                    No  ST (Standard)
# freq          238                 58148          57378
# mean          NaN                   NaN            NaN
# std           NaN                   NaN            NaN
# min           NaN                   NaN            NaN
# 25%           NaN                   NaN            NaN
# 50%           NaN                   NaN            NaN
# 75%           NaN                   NaN            NaN
# max           NaN                   NaN            NaN
#
#                                       English descriptors  \
# count                                               58525
# unique                                              46850
# top     LIGHTING EQUIPMENT; LAMP BASES; LAMP CAPS; INT...
# freq                                                   39
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                             English title  \
# count                                               56873
# unique                                              50915
# top     Lamp caps and holders together with gauges for...
# freq                                                   38
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                        French descriptors  ...    \
# count                                               58527  ...
# unique                                              46752  ...
# top     MATERIEL D'ECLAIRAGE; CULOT DE LAMPE; DOUILLE ...  ...
# freq                                                   40  ...
# mean                                                  NaN  ...
# std                                                   NaN  ...
# min                                                   NaN  ...
# 25%                                                   NaN  ...
# 50%                                                   NaN  ...
# 75%                                                   NaN  ...
# max                                                   NaN  ...
#
#                        Replacing                 Replacing later  \
# count                      18558                             501
# unique                     17410                             437
# top     Z68-300:198906 (Z68-300)  NF EN 28662-1:199304 (E90-320)
# freq                          13                              11
# mean                         NaN                             NaN
# std                          NaN                             NaN
# min                          NaN                             NaN
# 25%                          NaN                             NaN
# 50%                          NaN                             NaN
# 75%                          NaN                             NaN
# max                          NaN                             NaN
#
#        Revision drafts identifiers                   Revision of Selling  \
# count                         2318                          2871   60191
# unique                        2138                          2692       3
# top             PR EN 60730-1:2012  NF ISO 7001:200801 (X05-010)   AFNOR
# freq                             7                            17   46837
# mean                           NaN                           NaN     NaN
# std                            NaN                           NaN     NaN
# min                            NaN                           NaN     NaN
# 25%                            NaN                           NaN     NaN
# 50%                            NaN                           NaN     NaN
# 75%                            NaN                           NaN     NaN
# max                            NaN                           NaN     NaN
#
#        Withdrawal date                                            html_en  \
# count            26246                                               3377
# unique            2274                                               3377
# top         2017-08-12  /en-US/sw/Consultation/Xml/1416297/?lng=EN&sup...
# freq               362                                                  1
# mean               NaN                                                NaN
# std                NaN                                                NaN
# min                NaN                                                NaN
# 25%                NaN                                                NaN
# 50%                NaN                                                NaN
# 75%                NaN                                                NaN
# max                NaN                                                NaN
#
#                                                   html_fr  \
# count                                               37755
# unique                                              37754
# top     /en-US/sw/Consultation/Xml/1241047/?lng=FR&sup...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                   members  query
# count                                               23384  60310
# unique                                              18006  11427
# top     ABRAHAM : BULL SA|ALARD : WAVECOM|ALIAGA : EUR...  STILL
# freq                                                  130   1164
# mean                                                  NaN    NaN
# std                                                   NaN    NaN
# min                                                   NaN    NaN
# 25%                                                   NaN    NaN
# 50%                                                   NaN    NaN
# 75%                                                   NaN    NaN
# max                                                   NaN    NaN
#
# [11 rows x 42 columns]

# %%
withdrawn.to_csv('data\\afnor\\complete_unique.csv', sep=";", index=False, quotechar='"', quoting=csv.QUOTE_ALL)

# %%
keep_cols = ["Publication date", "Withdrawal date", "query", "Official identifier", "English title"]
df_red = df[keep_cols]

# %%
df_red.describe()
# Out:
#        Publication date Withdrawal date    query Official identifier  \
# count             50515           14860    50734               50515
# unique             1030            1005      663               20361
# top          2004-12-01      2010-01-28  LEGRAND        BP X30-323-0
# freq                470             231     1887                  30
#
#                                             English title
# count                                               50470
# unique                                              20294
# top     General principles for an environmental commun...
# freq                                                   30

# %%
df_red.to_csv(out, sep=";", index=False, quotechar='"', quoting=csv.QUOTE_ALL)
